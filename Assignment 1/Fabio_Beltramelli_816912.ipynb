# %% [markdown]
# # Import Librerie

# %%
from keras import *
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from keras.layers import Activation, LeakyReLU, Dropout
from keras.optimizers import SGD
from tensorflow.keras.activations import sigmoid
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import os 
import statistics
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %% [markdown]
# # Import File

# %%
# Commands if you are using google colab

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-24714ced-f238-422e-9b21-f93024d719d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24714ced-f238-422e-9b21-f93024d719d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving X_test.csv to X_test.csv
# Saving X_train.csv to X_train.csv
# Saving y_train.csv to y_train.csv
# {'X_test.csv': b',latitude,longitude,minimum_nights,number_of_reviews,reviews_per_month,calculated_host_listings_count,availability_365,Private_room,Entire_home/apt\n0,40.68579,-73.97455,2,4,0.17,1,0,0,1\n1,40.67085,-73.92316,1,9,0.61,1,0,1,0\n2,40.68817,-73.91523000000002,2,31,1.35,5,0,1,0\n3,40.67201,-73.86944,3,0,0.0,2,363,1,0\n4,40.68696,-73.92905,1,7,0.19,1,0,1,0\n5,40.80917,-73.95405,3,104,2.07,2,266,0,1\n6,40.70499,-73.91304000000002,3,0,0.0,1,0,0,1\n7,40.68502,-73.96073,1,150,2.98,1,300,0,1\n8,40.70735,-74.00971,5,18,0.29,1,179,0,1\n9,40.66909,-73.95144,1,0,0.0,1,0,0,1\n10,40.71509,-73.98992,3,4,0.19,1,3,0,1\n11,40.76389,-73.91963,4,0,0.0,1,38,1,0\n12,40.69094000000001,-73.95144,3,5,0.27,3,65,1,0\n13,40.71201,-73.96144,2,6,0.25,1,0,0,1\n14,40.64345,-73.98258,1,0,0.0,1,0,1,0\n15,40.61354,-73.96316,1,0,0.0,1,364,1,0\n16,40.72755,-73.97876,2,156,3.9,1,197,1,0\n17,40.69414,-73.92877,2,4,0.11,1,0,1,0\n18,40.73147,-73.98825,1,8,6.49,1,65,0,1\n19,40.72033,-73.98767,1,9,0.24,1,0,0,1\n20,40.69034,-73.86268000000003,2,9,1.03,2,180,1,0\n21,40.58848,-73795.0,1,11,3.79,1,113,0,1\n22,40.74465,-73.98535,2,84,4.03,4,103,1,0\n23,40.74737,-73.9742,2,4,1.06,327,99,0,1\n24,40.76214,-73.99899,30,0,0.0,8,129,0,1\n25,40.71104,-73.96113000000003,5,10,0.23,1,32,0,1\n26,40.70444000000001,-73.92181,2,0,0.0,1,0,1,0\n27,40.65925,-73.94861999999998,1,1,0.12,1,365,0,1\n28,40687.0,-73.93446,5,91,1.18,3,248,0,0\n29,40.76803,-73.98767,2,83,1.01,1,105,0,1\n30,40.75868,-73.92615,2,128,3.65,1,255,0,1\n31,40.78334,-73.97452,1,171,4.63,3,121,0,1\n32,40.79218,-73.97926,2,165,1.92,1,259,0,1\n33,40.63921,-74.02474000000002,3,19,2.75,1,52,0,1\n34,40.77497,-73.98788,3,8,1.21,2,0,0,1\n35,40.80069,-73.95340999999998,28,2,0.07,4,365,1,0\n36,40.77054,-73.99305,2,1,1.0,1,8,0,1\n37,40.73013,-74.00171999999998,1,1,0.02,1,0,1,0\n38,40.76284,-73.96038,1,25,0.67,1,0,0,1\n39,40.71124,-73.95716999999998,1,63,1.27,1,0,0,1\n
n412,100\n413,84\n414,300\n415,89\n416,1200\n417,207\n418,47\n419,185\n420,250\n421,228\n422,219\n423,39\n424,180\n425,200\n426,135\n427,35\n428,150\n429,76\n430,190\n431,42\n432,30\n433,299\n434,60\n435,50\n436,52\n437,125\n438,115\n439,999\n440,42\n441,55\n442,149\n443,149\n444,48\n445,100\n446,240\n447,151\n448,600\n449,110\n450,67\n451,317\n452,160\n453,130\n454,200\n455,40\n456,199\n457,24\n458,80\n459,88\n460,40\n461,123\n462,300\n463,40\n464,300\n465,33\n466,85\n467,129\n468,75\n469,400\n470,158\n471,60\n472,70\n473,44\n474,120\n475,89\n476,99\n477,250\n4 ...

# %% [markdown]
# ## Utility

# %%
def preprocess_data(X, scaler=None):
    """Preprocess input data by standardise features 
    by removing the mean and scaling to unit variance"""
    if not scaler:
        scaler = MinMaxScaler()
        scaler.fit(X)
    X = scaler.transform(X)
    return X, scaler

# %% [markdown]
# ## Caricamento Dati & Analisi iniziale

# %%
x_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")

#Rimozione Colonne ID
x_train.drop(['Unnamed: 0'], axis=1, inplace=True)
y_train.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
x_train.head()
# Out:
#       latitude  longitude  ...  Private_room  Entire_home/apt
# 0     40.71239  -73.95271  ...             1                0
# 1  40696.00000  -73.91303  ...             1                0
# 2     40.62707  -74.02817  ...             0                0
# 3     40.77910  -73.98565  ...             0                1
# 4     40.75777  -73.93509  ...             1                0
#
# [5 rows x 9 columns]

# %%
y_train.head()
# Out:
#    price
# 0     65
# 1     57
# 2    225
# 3    175
# 4    125

# %%
x_train.describe()
# Out:
#            latitude     longitude  ...  Private_room  Entire_home/apt
# count  33884.000000  33884.000000  ...  33884.000000     33884.000000
# mean     393.742123   -767.324528  ...      0.456085         0.520127
# std     3773.366411   7123.758128  ...      0.498075         0.499602
# min       40.499790 -74142.000000  ...      0.000000         0.000000
# 25%       40.690427    -73.983503  ...      0.000000         0.000000
# 50%       40.723645    -73.956025  ...      0.000000         1.000000
# 75%       40.763910    -73.937005  ...      1.000000         1.000000
# max    40894.000000    -73.712990  ...      1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
y_train.describe()
# Out:
#               price
# count  33884.000000
# mean     153.605389
# std      249.102710
# min        0.000000
# 25%       69.000000
# 50%      106.000000
# 75%      175.000000
# max    10000.000000

# %%
x_train.dtypes
# Out:
# latitude                          float64
# longitude                         float64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# Private_room                        int64
# Entire_home/apt                     int64
# dtype: object

# %%
x_train.isnull().sum()
# Out:
# latitude                          0
# longitude                         0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# Private_room                      0
# Entire_home/apt                   0
# dtype: int64

# %% [markdown]
# ##Correlazione tra feature e target
# Inizialmente è stato pensato di eseguire feature selection, in modo da rimuovere tutte quelle feature con basso grado di correlazione con la variabile target minore (es Minimum_Nights). Però questo approccio è stato abbandonato in quanto non ha portato ad un significativo incremento delle performance del modello. Quindi il modello è stato allenato utilizzando tutte le feature del dataset.

# %%
dataset = x_train
dataset = dataset.assign(price = y_train) 
corr = dataset.corr(method='pearson')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# E' stata applicata una normalizzazione ai valori di train (sia le feature sia la variabile target) in modo da riportare i valori in un range compreso tra 0 e 1

# %%
x_train, scaler = preprocess_data(x_train)
y_train, scaler1 = preprocess_data(y_train)

# %%
print(x_train[0])
print('Train dimensions:', x_train.shape)
# Out:
# [5.20396047e-06 9.99996764e-01 3.00300300e-03 3.17965024e-03
#  3.24786325e-03 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00]
# Train dimensions: (33884, 9)

# %%
print('Minimum value of the target variable:', int(y_train.min()))
print('Maximum value of the target variable:', int(y_train.max()))
print('Target dims', y_train.shape)
# Out:
# Minimum value of the target variable: 0
# Maximum value of the target variable: 1
# Target dims (33884, 1)

# %% [markdown]
# ## GridSearch

# %% [markdown]
# Per trovare i parametri migliori per allenare la rete è stata applicata una tecnica di GridSearch. Questa consiste nel provare diversi tipi di parametri iniziali e al termine dell'esecuzione vengono restituiti i parametri migliori che hanno ottimizzato al meglio la metrica richiesta.
#
# La funzione FindLayerNodesLinear restituisce il numero di neuroni per ogni hidden layer in modo decrescente, partendo dal numero di input e arrivando a quello di output.
#
# La funzione createmodel serve a creare la rete vera e propria, è composta da n layers in base al parametro in input e ogni livello conterrà un numero differente di neuroni in base al layer.
#
# Per allenare questo modello è stata fissata sia la funzione di attivazione (relu hidden layer e sigmoid output layer), sia la loss function (mse) e anche la metrica (rmse). In questo modo è stato possibile concentrarsi maggiormente sulla struttura della rete.
#
# I parametri passati in fase di training sono diversi:
# - n_layers=[3,4,5] => permette di capire quanti livelli dovrebbe avere la rete. L'analisi è stata fatta solo tra 3 e 5 livelli, perché aumentando il numero la fase di training diventava troppo onerosa.
#
# - first_layer_nodes = [256,128,64] => permette di capire quanti neuroni dovrebbe avere il primo layer.
#
# - last_layer_nodes = [64,32,16] => permette di capire quanti neuroni dovrebbe avere l'ultimo layer.
#
# - batch_size = [64,128,256] => permette di capire quale è la batch size migliore.
#
# - epochs = [10,20] => permette di capire quale è il numero di epochs migliore.
# E' stato scelto di avere numero basso di epochs perché altrimenti il training diventava troppo oneroso.
#
# Dopo l'esecuzione del comando grid.fit(X_train, y_train) sono stati trovati questi parametri ottimi:
# {'batch_size': 64, 'epochs': 20, 'first_layer_nodes': 128, 'last_layer_nodes': 16, 'n_layers': 5}
#
# Da questi parametri si è deciso di partire per allenare la rete vera e propria, formata da 5 livelli con 128 units al primo e all'ultimo solo 16.
# Utilizzando la funzione FindLayerNodesLinear(5, 128, 16) si possono vedere i neurons per ogni livello.
#
# [128, 100, 72, 44, 16]
#
# Reference: https://datagraphi.com/blog/post/2019/12/17/how-to-find-the-optimum-number-of-hidden-layers-and-nodes-in-a-neural-network-model

# %%
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

def FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes):
    layers = []

    nodes_increment = (last_layer_nodes - first_layer_nodes)/ (n_layers-1)
    nodes = first_layer_nodes
    for i in range(1, n_layers+1):
        layers.append(math.ceil(nodes))
        nodes = nodes + nodes_increment

    return layers

def rmse(y_true, y_pred):
  return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

def createmodel(n_layers, first_layer_nodes, last_layer_nodes):
    model = Sequential()
    n_nodes = FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(first_layer_nodes, input_dim=X_train.shape[1], activation='relu'))
        else:
            model.add(Dense(n_nodes[i-1], activation='relu'))

    model.add(Dense(y_train.shape[1], activation='sigmoid'))
    model.compile(optimizer='adam', loss='mse', metrics = [rmse])

    return model

#CODICE COMMENTATO IN QUANTO L'ESECUZIONE HA RICHIESTO PARECCHI MINUTI (CIRCA 50MIN)

#model = KerasRegressor(build_fn=createmodel, verbose = False)

#param_grid = dict(n_layers=[3,4,5], first_layer_nodes = [256,128,64], last_layer_nodes = [64,32,16], batch_size = [64,128,256], epochs = [10,20])

#grid = GridSearchCV(estimator = model, param_grid = param_grid)

#grid.fit(X_train, y_train)

# %%
#print("Best using %s" % (grid.best_params_))
#Best using {'batch_size': 64, 'epochs': 20, 'first_layer_nodes': 128, 'last_layer_nodes': 16, 'n_layers': 5}

# %%
FindLayerNodesLinear(5, 128, 16)
#[128, 100, 72, 44, 16]
# Out:
# [128, 100, 72, 44, 16]

# %% [markdown]
# ## Train & Test

# %% [markdown]
# E' stata costruita la rete utilizzando le metriche trovate prima, sono stati introdotti due livelli di Dropout in modo da evitare che la rete overfitti troppo. Per evitare questo è stato anche introdotto il EarlyStopping con patience = 10, in modo che dopo 10 epochs senza nessun miglioramento rispetto alla loss function il training venga stoppato.
#
# Sono state utilizzate tutte le funzioni di attivazione in fase di allenamento del modello.
#
# Come loss function è stato provato sia mean_squared_logarithmic_error che mse e non sono state trovate particolari differenze nei risultati. Mentre per quanto riguarda l'optimizer è stato provato un approccio SGD, ma le performance sono decisamente peggiorate, quindi è stato utilizzato un ottimizzatore base come adam.

# %%
X_train, X_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size=0.2, random_state=0)

# %%
def NeuralNetwork(X, activation, n_outputs):
    inputs = Input(shape = (X.shape[1]))
    x = layers.Dense(128, activation = activation) (inputs)
    x = layers.Dense(100, activation = activation) (x)
    x = layers.Dense(72, activation = activation) (x)
    x = Dropout(0.3) (x)
    x = layers.Dense(44, activation = activation) (x)
    x = layers.Dense(16, activation = activation) (x)
    x = Dropout(0.3) (x)
    output = layers.Dense(n_outputs, activation = 'sigmoid') (x)
    model = Model(inputs, output)
    model.compile(loss = 'mse', optimizer='adam', metrics = [tf.keras.metrics.RootMeanSquaredError()]) 
    return model

# %%
def gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

def swish(x, beta = 1):
    return (x * sigmoid(beta * x))

get_custom_objects().update({'gelu': Activation(gelu)})
get_custom_objects().update({'leaky-relu': Activation(LeakyReLU(alpha=0.2))})
get_custom_objects().update({'swish': Activation(swish)})

act_func = ['relu', 'elu', 'leaky-relu', 'selu', 'gelu', 'softmax', 'swish']

# %%
result = []
for activation in act_func:
    print('\nTraining with -->{0}<-- activation function\n'.format(activation))
    dims = y_train.shape[1]
    model = NeuralNetwork(activation=activation, X = X_train, n_outputs=dims)
    
    history = model.fit(X_train, y_train,
          batch_size=64,
          epochs=50,
          verbose=0,
          validation_data=(X_validation, y_validation),
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', mode='min', patience=10)]) # EarlyStopping patient 10 epoch
    
    result.append(history)
    
    K.clear_session()
    del model
# Out:
# Training with -->relu<-- activation function
#
#
# Training with -->elu<-- activation function
#
#
# Training with -->leaky-relu<-- activation function
#
#
# Training with -->selu<-- activation function
#
#
# Training with -->gelu<-- activation function
#
#
# Training with -->softmax<-- activation function
#
#
# Training with -->swish<-- activation function

# %%
rmse_finale = []

def risultati(activation_function, rmse):
    for i in range(len(activation_function)):
        print('RMSE of the activation function {} is {}'.format(activation_function[i], round(rmse[i], 5)))
        
def plot_act_func_results(results, activation_functions = []):
    plt.figure(figsize=(10,7))
    plt.style.use('dark_background')
    
    # Plot of the validation root mean squared error
    plt.figure(figsize=(10,10))
    
    for act_func in results:
        plt.plot(act_func.history['val_root_mean_squared_error'])
        rmse_finale.append(act_func.history['val_root_mean_squared_error'][-1])
    
    plt.title('Model RMSE')
    plt.ylabel('Validation RMSE')
    plt.xlabel('Epoch')
    plt.legend(activation_functions)
    plt.show()

plot_act_func_results(result, act_func)

# %%
risultati(act_func,rmse_finale)
#RMSE of the activation function relu is 0.02708
#RMSE of the activation function elu is 0.02138
#RMSE of the activation function leaky-relu is 0.02138
#RMSE of the activation function selu is 0.02142
#RMSE of the activation function gelu is 0.02708
#RMSE of the activation function softmax is 0.02246
#RMSE of the activation function swish is 0.02153
# Out:
# RMSE of the activation function relu is 0.02708
# RMSE of the activation function elu is 0.02138
# RMSE of the activation function leaky-relu is 0.02138
# RMSE of the activation function selu is 0.02142
# RMSE of the activation function gelu is 0.02708
# RMSE of the activation function softmax is 0.02246
# RMSE of the activation function swish is 0.02153

# %% [markdown]
# ## Predict
#
# E' possibile vedere come la funzione di attivazione con valore minore di RMSE è la Leaky-RELU con un valore di 0.02133. Pertanto è stata selezionata per allenare il modello definitivo

# %%
activation = 'leaky-relu'

model = NeuralNetwork(activation=activation, X = X_train, n_outputs=dims)
model.summary()
model.fit(X_train, y_train,
          batch_size=64,
          epochs=50,
          verbose=1,
          validation_data=(X_validation, y_validation),
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', mode='min', patience=10)])
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 9)]               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               12900
# _________________________________________________________________
# dense_8 (Dense)              (None, 72)                7272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 72)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 44)                3212
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                720
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 25,401
# Trainable params: 25,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 424/424 [==============================] - 1s 3ms/step - loss: 0.0060 - root_mean_squared_error: 0.0776 - val_loss: 7.3309e-04 - val_root_mean_squared_error: 0.0271
# Epoch 2/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.9080e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3321e-04 - val_root_mean_squared_error: 0.0271
# Epoch 3/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.8969e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3327e-04 - val_root_mean_squared_error: 0.0271
# Epoch 4/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.9086e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3329e-04 - val_root_mean_squared_error: 0.0271
# Epoch 5/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.8579e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3323e-04 - val_root_mean_squared_error: 0.0271
# Epoch 6/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.8832e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3327e-04 - val_root_mean_squared_error: 0.0271
# Epoch 7/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.8685e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.3312e-04 - val_root_mean_squared_error: 0.0271
# Epoch 8/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.8438e-04 - root_mean_squared_error: 0.0297 - val_loss: 7.3208e-04 - val_root_mean_squared_error: 0.0271
# Epoch 9/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.5641e-04 - root_mean_squared_error: 0.0293 - val_loss: 6.5832e-04 - val_root_mean_squared_error: 0.0257
# Epoch 10/50
# 424/424 [==============================] - 1s 3ms/step - loss: 8.0236e-04 - root_mean_squared_error: 0.0283 - val_loss: 5.7307e-04 - val_root_mean_squared_error: 0.0239
# Epoch 11/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.8545e-04 - root_mean_squared_error: 0.0280 - val_loss: 5.4206e-04 - val_root_mean_squared_error: 0.0233
# Epoch 12/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.7003e-04 - root_mean_squared_error: 0.0277 - val_loss: 6.2623e-04 - val_root_mean_squared_error: 0.0250
# Epoch 13/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.6016e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.7239e-04 - val_root_mean_squared_error: 0.0239
# Epoch 14/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.6148e-04 - root_mean_squared_error: 0.0276 - val_loss: 6.6257e-04 - val_root_mean_squared_error: 0.0257
# Epoch 15/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.5431e-04 - root_mean_squared_error: 0.0275 - val_loss: 5.0033e-04 - val_root_mean_squared_error: 0.0224
# Epoch 16/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.5192e-04 - root_mean_squared_error: 0.0274 - val_loss: 5.2792e-04 - val_root_mean_squared_error: 0.0230
# Epoch 17/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.4744e-04 - root_mean_squared_error: 0.0273 - val_loss: 5.0541e-04 - val_root_mean_squared_error: 0.0225
# Epoch 18/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.4052e-04 - root_mean_squared_error: 0.0272 - val_loss: 6.0292e-04 - val_root_mean_squared_error: 0.0246
# Epoch 19/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.3765e-04 - root_mean_squared_error: 0.0272 - val_loss: 5.3028e-04 - val_root_mean_squared_error: 0.0230
# Epoch 20/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.3087e-04 - root_mean_squared_error: 0.0270 - val_loss: 5.7724e-04 - val_root_mean_squared_error: 0.0240
# Epoch 21/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.2889e-04 - root_mean_squared_error: 0.0270 - val_loss: 5.0086e-04 - val_root_mean_squared_error: 0.0224
# Epoch 22/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.1385e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8386e-04 - val_root_mean_squared_error: 0.0220
# Epoch 23/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.1101e-04 - root_mean_squared_error: 0.0267 - val_loss: 5.1146e-04 - val_root_mean_squared_error: 0.0226
# Epoch 24/50
# 424/424 [==============================] - 1s 3ms/step - loss: 7.0698e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.9017e-04 - val_root_mean_squared_error: 0.0221
# Epoch 25/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.9255e-04 - root_mean_squared_error: 0.0263 - val_loss: 5.0369e-04 - val_root_mean_squared_error: 0.0224
# Epoch 26/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.9329e-04 - root_mean_squared_error: 0.0263 - val_loss: 5.0246e-04 - val_root_mean_squared_error: 0.0224
# Epoch 27/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.8115e-04 - root_mean_squared_error: 0.0261 - val_loss: 4.8547e-04 - val_root_mean_squared_error: 0.0220
# Epoch 28/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.7346e-04 - root_mean_squared_error: 0.0260 - val_loss: 4.9140e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.6712e-04 - root_mean_squared_error: 0.0258 - val_loss: 4.7723e-04 - val_root_mean_squared_error: 0.0218
# Epoch 30/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.5956e-04 - root_mean_squared_error: 0.0257 - val_loss: 4.7018e-04 - val_root_mean_squared_error: 0.0217
# Epoch 31/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.5651e-04 - root_mean_squared_error: 0.0256 - val_loss: 4.6945e-04 - val_root_mean_squared_error: 0.0217
# Epoch 32/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.5062e-04 - root_mean_squared_error: 0.0255 - val_loss: 4.6272e-04 - val_root_mean_squared_error: 0.0215
# Epoch 33/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.4760e-04 - root_mean_squared_error: 0.0254 - val_loss: 4.6692e-04 - val_root_mean_squared_error: 0.0216
# Epoch 34/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.4167e-04 - root_mean_squared_error: 0.0253 - val_loss: 4.6003e-04 - val_root_mean_squared_error: 0.0214
# Epoch 35/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.3480e-04 - root_mean_squared_error: 0.0252 - val_loss: 4.5717e-04 - val_root_mean_squared_error: 0.0214
# Epoch 36/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.3423e-04 - root_mean_squared_error: 0.0252 - val_loss: 4.6746e-04 - val_root_mean_squared_error: 0.0216
# Epoch 37/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.3156e-04 - root_mean_squared_error: 0.0251 - val_loss: 4.5676e-04 - val_root_mean_squared_error: 0.0214
# Epoch 38/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.2648e-04 - root_mean_squared_error: 0.0250 - val_loss: 4.5567e-04 - val_root_mean_squared_error: 0.0213
# Epoch 39/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.2283e-04 - root_mean_squared_error: 0.0250 - val_loss: 4.5638e-04 - val_root_mean_squared_error: 0.0214
# Epoch 40/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.2533e-04 - root_mean_squared_error: 0.0250 - val_loss: 4.6637e-04 - val_root_mean_squared_error: 0.0216
# Epoch 41/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.1853e-04 - root_mean_squared_error: 0.0249 - val_loss: 4.5392e-04 - val_root_mean_squared_error: 0.0213
# Epoch 42/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.1840e-04 - root_mean_squared_error: 0.0249 - val_loss: 4.6058e-04 - val_root_mean_squared_error: 0.0215
# Epoch 43/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.1505e-04 - root_mean_squared_error: 0.0248 - val_loss: 4.5815e-04 - val_root_mean_squared_error: 0.0214
# Epoch 44/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.1380e-04 - root_mean_squared_error: 0.0248 - val_loss: 4.5499e-04 - val_root_mean_squared_error: 0.0213
# Epoch 45/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.1014e-04 - root_mean_squared_error: 0.0247 - val_loss: 4.5453e-04 - val_root_mean_squared_error: 0.0213
# Epoch 46/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.0916e-04 - root_mean_squared_error: 0.0247 - val_loss: 4.5610e-04 - val_root_mean_squared_error: 0.0214
# Epoch 47/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.0860e-04 - root_mean_squared_error: 0.0247 - val_loss: 4.5447e-04 - val_root_mean_squared_error: 0.0213
# Epoch 48/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.0744e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.6407e-04 - val_root_mean_squared_error: 0.0215
# Epoch 49/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.0757e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.5587e-04 - val_root_mean_squared_error: 0.0214
# Epoch 50/50
# 424/424 [==============================] - 1s 3ms/step - loss: 6.0586e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.6332e-04 - val_root_mean_squared_error: 0.0215

# %%
x_test = pd.read_csv("X_test.csv")
x_test.drop(['Unnamed: 0'], axis=1, inplace=True)
x_test, scaler = preprocess_data(x_test)

# %%
y_test = model.predict(x_test)

# %%
y_test_final = scaler1.inverse_transform(y_test)
y_test_final = np.rint(y_test_final)
print(y_test_final)
# Out:
# [[214.]
#  [ 73.]
#  [ 67.]
#  ...
#  [209.]
#  [229.]
#  [ 88.]]

# %%
with open("Fabio_Beltramelli_816912_score1.txt", 'w') as f:
    for item in y_test_final:
        f.write("%s\n" % item)
